# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Project_NLP/TranMinhDuy/cleaned_dataset.csv')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15922 entries, 0 to 15921
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0.1     15922 non-null  int64
#  1   Unnamed: 0       9709 non-null   float64
#  2   url              15922 non-null  object
#  3   title            15922 non-null  object
#  4   summary          15922 non-null  object
#  5   full_text        15922 non-null  object
#  6   full_text_token  15922 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 870.9+ KB

# %%
dataset['full_text'].describe()
# Out:
# count                                                 15922
# unique                                                15898
# top       Đây là những câu đố không chỉ giúp bạn ôn lại ...
# freq                                                     16
# Name: full_text, dtype: object

# %%
dataset[dataset['full_text_token'] > 1024]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, url, title, summary, full_text, full_text_token]
# Index: []

# %%
df = pd.DataFrame(dataset)
label_counts = df['label'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-6-2060418310.py in <cell line: 0>()
#       1 df = pd.DataFrame(dataset)
# ...

# %%
plt.figure(figsize=(6,6))
plt.pie(label_counts, labels=label_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Tỉ lệ các nhãn trong tập dữ liệu')
plt.axis('equal')  # Đảm bảo hình tròn
plt.legend(title=':Label')
plt.show()

# %%
df['label'].value_counts()
# Out:
# label
# 1    25408
# 0    21428
# Name: count, dtype: int64

# %%
df['post_message'] = [text.strip() for text in df['poss_message']]
df['text']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-11-1851315201.py in <cell line: 0>()
# ----> 1 df['text'] = [text.strip() for text in df['text']]
# ...
